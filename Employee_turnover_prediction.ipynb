# %%
import numpy as np
import pandas as pd                               #loading the libraries
import matplotlib.pyplot as plt
import seaborn as sn

# %%
data=pd.read_csv('/content/drive/MyDrive/WA_Fn-UseC_-HR-Employee-Attrition.csv')     #loading the datasets

# %%
data.head()   #showing the first 5 rows
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()   #showing the last 5 rows
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.shape  #shape of the data
# Out:
# (1470, 35)

# %%
data.columns      #colums in the data
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.info()    #showing info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.isnull().sum()        #checking the null values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.dtypes         #checking the data types
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
data.drop('Over18',axis='columns',inplace=True)    #droping the some of the columns

# %%
data        #data after droping some of the columns
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data['Attrition'].unique() #checking the values in the column
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['Attrition'].replace({'Yes':0,'No':1},inplace=True)    #replace the string values into numerical values

# %%
data['BusinessTravel'].unique()    #checking the values in the column
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
data['BusinessTravel'].replace({'Travel_Rarely':0,'Travel_Frequently':1,'Non-Travel':2},inplace=True) #replace the string values into numerical values

# %%
data['Department'].unique()    #checking the values in the column
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
data['Department'].replace({'Sales':0,'Research & Development':1,'Human Resources':2},inplace=True)   #replace the string values into numerical values

# %%
data['EducationField'].unique()   #checking the values in the column
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
data['EducationField'].replace({'Life Sciences':0,'Other':1,'Medical':2,'Marketing':3,'Technical Degree':4,'Human Resources':5},inplace=True)   #replace the string values into numerical values

# %%
data['Gender'].unique()   #checking the values in the column
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
data['Gender'].replace({'Female':0,'Male':1},inplace=True)   #replace the string values into numerical values

# %%
data['JobRole'].unique()   #checking the values in the column
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
data['JobRole'].replace({'Sales Executive':0,'Research Scientist':1,'Laboratory Technician':2,'Manufacturing Director':3,'Healthcare Representative':4,'Manager':5,'Sales Representative':6,'Research Director':7,'Human Resources':8},inplace=True)   #replace the string values into numerical values

# %%
data['MaritalStatus'].unique()    #checking the values in the column
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
data['MaritalStatus'].replace({'Single':0,'Married':1,'Divorced':2},inplace=True)  #replace the string values into numerical values

# %%
data['OverTime'].unique()   #checking the values in the column
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['OverTime'].replace({'Yes':0,'No':1},inplace=True)   #replace the string values into numerical values

# %%
data    #data after replacing the numerial values
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          0               0       1102           0                 1
# 1      49          1               1        279           1                 8
# 2      37          0               0       1373           1                 2
# 3      33          1               1       1392           1                 3
# 4      27          1               0        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          1               1        884           1                23
# 1466   39          1               0        613           1                 6
# 1467   27          1               0        155           1                 4
# 1468   49          1               1       1023           0                 2
# 1469   34          1               0        628           1                 8
#
# ...

# %%
data.dtypes   #checking the datatypes
# Out:
# Age                         int64
# Attrition                   int64
# BusinessTravel              int64
# DailyRate                   int64
# Department                  int64
# DistanceFromHome            int64
# Education                   int64
# EducationField              int64
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int64
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int64
# JobSatisfaction             int64
# MaritalStatus               int64
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int64
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# StockOptionLevel            int64
# ...

# %%
sn.barplot(data)   #DataVisulalization
# Out:
# <Axes: >

# %%
sn.lineplot(x='Department',y='OverTime',data=data)   #DataVisulalization
# Out:
# <Axes: xlabel='Department', ylabel='OverTime'>

# %%
data.hist(figsize=(20,20));    #DataVisulalization

# %%
plt.bar(data['Attrition'].unique(), data['Attrition'].value_counts(), color=['red', 'green']);   #DataVisulalization

# %%
plt.bar(data['BusinessTravel'].unique(), data['BusinessTravel'].value_counts(), color=['red', 'green']);    #DataVisulalization

# %%
plt.bar(data['OverTime'].unique(), data['OverTime'].value_counts(), color=['red', 'green']);   #DataVisulalization

# %%
X=data.drop('OverTime',axis=1)   #droping the target value

# %%
X
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          0               0       1102           0                 1
# 1      49          1               1        279           1                 8
# 2      37          0               0       1373           1                 2
# 3      33          1               1       1392           1                 3
# 4      27          1               0        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          1               1        884           1                23
# 1466   39          1               0        613           1                 6
# 1467   27          1               0        155           1                 4
# 1468   49          1               1       1023           0                 2
# 1469   34          1               0        628           1                 8
#
# ...

# %%
Y=data['OverTime']   #loading the target value

# %%
Y
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    0
# 1468    1
# 1469    1
# Name: OverTime, Length: 1470, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)     #spliting the data

# %%
from sklearn.ensemble import RandomForestClassifier    #importing the algorithm

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train, Y_train)   #fiting the model
# Out:
# RandomForestClassifier()

# %%
prediction=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test,prediction)
# Out:
# 0.7040816326530612
